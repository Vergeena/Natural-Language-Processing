# %%
import pandas as pd

# %%
df=pd.read_csv("WA with Elil Greens.txt",header=None,error_bad_lines=False,encoding="utf8")
# Out:
# C:\Anaconda\envs\ai\lib\site-packages\IPython\core\interactiveshell.py:3553: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version.
#
#
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
df
# Out:
#           0                                                  1  \
# 0    1/6/23   9:39 AM - Messages and calls are end-to-end e...
# 1    1/6/23                          9:39 AM - Elil Greens: Hi
# 2    1/6/23   9:39 AM - Elil Greens: I am Ezhilarasan from ...
# 3    1/6/23   9:39 AM - Elil Greens: When will u free pls c...
# 4    1/6/23          10:05 AM - 🌚: Pls give the python content
# ..      ...                                                ...
# 111  3/3/23                              7:11 PM - 🌚: Sir link
# 112  3/3/23                                  7:20 PM - 🌚: Sir
# 113  3/3/23                                  7:49 PM - 🌚: Sir
# 114  3/5/23                     9:26 PM - Elil Greens: Hai all
# 115  3/5/23                                9:48 PM - 🌚: Ok sir
#
#                                                      2  \
# 0                                    not even WhatsApp
# 1                                                  NaN
# ...

# %%
df=df.drop(0)#row deleted

# %%
df
# Out:
#           0                                                  1  \
# 1    1/6/23                          9:39 AM - Elil Greens: Hi
# 2    1/6/23   9:39 AM - Elil Greens: I am Ezhilarasan from ...
# 3    1/6/23   9:39 AM - Elil Greens: When will u free pls c...
# 4    1/6/23          10:05 AM - 🌚: Pls give the python content
# 5    1/6/23                         10:08 AM - Elil Greens: ok
# ..      ...                                                ...
# 111  3/3/23                              7:11 PM - 🌚: Sir link
# 112  3/3/23                                  7:20 PM - 🌚: Sir
# 113  3/3/23                                  7:49 PM - 🌚: Sir
# 114  3/5/23                     9:26 PM - Elil Greens: Hai all
# 115  3/5/23                                9:48 PM - 🌚: Ok sir
#
#                                                      2    3
# 1                                                  NaN  NaN
# 2                                                  NaN  NaN
# ...

# %%
df=df.drop(2,axis=1)

# %%
df
# Out:
#           0                                                  1    3
# 1    1/6/23                          9:39 AM - Elil Greens: Hi  NaN
# 2    1/6/23   9:39 AM - Elil Greens: I am Ezhilarasan from ...  NaN
# 3    1/6/23   9:39 AM - Elil Greens: When will u free pls c...  NaN
# 4    1/6/23          10:05 AM - 🌚: Pls give the python content  NaN
# 5    1/6/23                         10:08 AM - Elil Greens: ok  NaN
# ..      ...                                                ...  ...
# 111  3/3/23                              7:11 PM - 🌚: Sir link  NaN
# 112  3/3/23                                  7:20 PM - 🌚: Sir   NaN
# 113  3/3/23                                  7:49 PM - 🌚: Sir   NaN
# 114  3/5/23                     9:26 PM - Elil Greens: Hai all  NaN
# 115  3/5/23                                9:48 PM - 🌚: Ok sir  NaN
#
# [115 rows x 3 columns]

# %%
df=df.drop(3,axis=1)

# %%
df
# Out:
#           0                                                  1
# 1    1/6/23                          9:39 AM - Elil Greens: Hi
# 2    1/6/23   9:39 AM - Elil Greens: I am Ezhilarasan from ...
# 3    1/6/23   9:39 AM - Elil Greens: When will u free pls c...
# 4    1/6/23          10:05 AM - 🌚: Pls give the python content
# 5    1/6/23                         10:08 AM - Elil Greens: ok
# ..      ...                                                ...
# 111  3/3/23                              7:11 PM - 🌚: Sir link
# 112  3/3/23                                  7:20 PM - 🌚: Sir
# 113  3/3/23                                  7:49 PM - 🌚: Sir
# 114  3/5/23                     9:26 PM - Elil Greens: Hai all
# 115  3/5/23                                9:48 PM - 🌚: Ok sir
#
# [115 rows x 2 columns]

# %%
df.columns=["Date","Chat"]

# %%
df
# Out:
#        Date                                               Chat
# 1    1/6/23                          9:39 AM - Elil Greens: Hi
# 2    1/6/23   9:39 AM - Elil Greens: I am Ezhilarasan from ...
# 3    1/6/23   9:39 AM - Elil Greens: When will u free pls c...
# 4    1/6/23          10:05 AM - 🌚: Pls give the python content
# 5    1/6/23                         10:08 AM - Elil Greens: ok
# ..      ...                                                ...
# 111  3/3/23                              7:11 PM - 🌚: Sir link
# 112  3/3/23                                  7:20 PM - 🌚: Sir
# 113  3/3/23                                  7:49 PM - 🌚: Sir
# 114  3/5/23                     9:26 PM - Elil Greens: Hai all
# 115  3/5/23                                9:48 PM - 🌚: Ok sir
#
# [115 rows x 2 columns]

# %%
message=df["Chat"].str.split("-",n=1,expand=True)

# %%
message
# Out:
#               0                                                  1
# 1      9:39 AM                                     Elil Greens: Hi
# 2      9:39 AM    Elil Greens: I am Ezhilarasan from Greens tec...
# 3      9:39 AM           Elil Greens: When will u free pls call me
# 4     10:05 AM                      🌚: Pls give the python content
# 5     10:08 AM                                     Elil Greens: ok
# ..          ...                                                ...
# 111    7:11 PM                                         🌚: Sir link
# 112    7:20 PM                                             🌚: Sir
# 113    7:49 PM                                             🌚: Sir
# 114    9:26 PM                                Elil Greens: Hai all
# 115    9:48 PM                                           🌚: Ok sir
#
# [115 rows x 2 columns]

# %%
df["Time"]=message[0]

# %%
df
# Out:
#        Date                                               Chat        Time
# 1    1/6/23                          9:39 AM - Elil Greens: Hi    9:39 AM
# 2    1/6/23   9:39 AM - Elil Greens: I am Ezhilarasan from ...    9:39 AM
# 3    1/6/23   9:39 AM - Elil Greens: When will u free pls c...    9:39 AM
# 4    1/6/23          10:05 AM - 🌚: Pls give the python content   10:05 AM
# 5    1/6/23                         10:08 AM - Elil Greens: ok   10:08 AM
# ..      ...                                                ...         ...
# 111  3/3/23                              7:11 PM - 🌚: Sir link    7:11 PM
# 112  3/3/23                                  7:20 PM - 🌚: Sir     7:20 PM
# 113  3/3/23                                  7:49 PM - 🌚: Sir     7:49 PM
# 114  3/5/23                     9:26 PM - Elil Greens: Hai all    9:26 PM
# 115  3/5/23                                9:48 PM - 🌚: Ok sir    9:48 PM
#
# [115 rows x 3 columns]

# %%
message1=message[1].str.split(":",n=1,expand=True)

# %%
message1
# Out:
#                 0                                         1
# 1     Elil Greens                                        Hi
# 2     Elil Greens   I am Ezhilarasan from Greens technology
# 3     Elil Greens              When will u free pls call me
# 4               🌚               Pls give the python content
# 5     Elil Greens                                        ok
# ..            ...                                       ...
# 111             🌚                                  Sir link
# 112             🌚                                      Sir
# 113             🌚                                      Sir
# 114   Elil Greens                                   Hai all
# 115             🌚                                    Ok sir
#
# [115 rows x 2 columns]

# %%
df["Name"]=message1[0]

# %%
df
# Out:
#        Date                                               Chat        Time  \
# 1    1/6/23                          9:39 AM - Elil Greens: Hi    9:39 AM
# 2    1/6/23   9:39 AM - Elil Greens: I am Ezhilarasan from ...    9:39 AM
# 3    1/6/23   9:39 AM - Elil Greens: When will u free pls c...    9:39 AM
# 4    1/6/23          10:05 AM - 🌚: Pls give the python content   10:05 AM
# 5    1/6/23                         10:08 AM - Elil Greens: ok   10:08 AM
# ..      ...                                                ...         ...
# 111  3/3/23                              7:11 PM - 🌚: Sir link    7:11 PM
# 112  3/3/23                                  7:20 PM - 🌚: Sir     7:20 PM
# 113  3/3/23                                  7:49 PM - 🌚: Sir     7:49 PM
# 114  3/5/23                     9:26 PM - Elil Greens: Hai all    9:26 PM
# 115  3/5/23                                9:48 PM - 🌚: Ok sir    9:48 PM
#
#              Name
# 1     Elil Greens
# 2     Elil Greens
# 3     Elil Greens
# ...

# %%
df["Chat"]=message1[1]

# %%
df
# Out:
#        Date                                      Chat        Time  \
# 1    1/6/23                                        Hi    9:39 AM
# 2    1/6/23   I am Ezhilarasan from Greens technology    9:39 AM
# 3    1/6/23              When will u free pls call me    9:39 AM
# 4    1/6/23               Pls give the python content   10:05 AM
# 5    1/6/23                                        ok   10:08 AM
# ..      ...                                       ...         ...
# 111  3/3/23                                  Sir link    7:11 PM
# 112  3/3/23                                      Sir     7:20 PM
# 113  3/3/23                                      Sir     7:49 PM
# 114  3/5/23                                   Hai all    9:26 PM
# 115  3/5/23                                    Ok sir    9:48 PM
#
#              Name
# 1     Elil Greens
# 2     Elil Greens
# 3     Elil Greens
# 4               🌚
# 5     Elil Greens
# ..            ...
# 111             🌚
# 112             🌚
# ...

# %%
df=df[["Date","Time","Name","Chat"]]

# %%
df
# Out:
#        Date        Time          Name  \
# 1    1/6/23    9:39 AM    Elil Greens
# 2    1/6/23    9:39 AM    Elil Greens
# 3    1/6/23    9:39 AM    Elil Greens
# 4    1/6/23   10:05 AM              🌚
# 5    1/6/23   10:08 AM    Elil Greens
# ..      ...         ...           ...
# 111  3/3/23    7:11 PM              🌚
# 112  3/3/23    7:20 PM              🌚
# 113  3/3/23    7:49 PM              🌚
# 114  3/5/23    9:26 PM    Elil Greens
# 115  3/5/23    9:48 PM              🌚
#
#                                          Chat
# 1                                          Hi
# 2     I am Ezhilarasan from Greens technology
# 3                When will u free pls call me
# 4                 Pls give the python content
# 5                                          ok
# ..                                        ...
# 111                                  Sir link
# 112                                      Sir
# 113                                      Sir
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 115 entries, 1 to 115
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    115 non-null    object
#  1   Time    71 non-null     object
#  2   Name    66 non-null     object
#  3   Chat    66 non-null     object
# dtypes: object(4)
# memory usage: 4.5+ KB

# %%
from nltk.sentiment.vader import SentimentIntensityAnalyzer
import nltk

# %%
dataset=df

# %%
dataset.dropna(inplace=True)
# Out:
# C:\Anaconda\envs\ai\lib\site-packages\pandas\util\_decorators.py:311: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return func(*args, **kwargs)

# %%
dataset
# Out:
#        Date        Time          Name  \
# 1    1/6/23    9:39 AM    Elil Greens
# 2    1/6/23    9:39 AM    Elil Greens
# 3    1/6/23    9:39 AM    Elil Greens
# 4    1/6/23   10:05 AM              🌚
# 5    1/6/23   10:08 AM    Elil Greens
# ..      ...         ...           ...
# 111  3/3/23    7:11 PM              🌚
# 112  3/3/23    7:20 PM              🌚
# 113  3/3/23    7:49 PM              🌚
# 114  3/5/23    9:26 PM    Elil Greens
# 115  3/5/23    9:48 PM              🌚
#
#                                          Chat
# 1                                          Hi
# 2     I am Ezhilarasan from Greens technology
# 3                When will u free pls call me
# 4                 Pls give the python content
# 5                                          ok
# ..                                        ...
# 111                                  Sir link
# 112                                      Sir
# 113                                      Sir
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 66 entries, 1 to 115
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    66 non-null     object
#  1   Time    66 non-null     object
#  2   Name    66 non-null     object
#  3   Chat    66 non-null     object
# dtypes: object(4)
# memory usage: 2.6+ KB

# %%
sia=SentimentIntensityAnalyzer()

# %%
senti=sia.polarity_scores(dataset['Chat'][4])

# %%
senti
# Out:
# {'neg': 0.0, 'neu': 0.755, 'pos': 0.245, 'compound': 0.0772}

# %%
def sentimentalAnalysis(dataset,columnName):    
    #downloading vader_lexicon for  the process
    import matplotlib.pyplot as plt
    import seaborn as sns
    "Import neccessary packages"
    from nltk.sentiment.vader import SentimentIntensityAnalyzer
    import nltk
    "Deleting null values"
    dataset.dropna(inplace=True)
    "Checking for the comment"
    #sia.polarity_scores(data[columnName][63])
    "Creating respective columns"
    dataset['scores']=dataset[columnName].apply(lambda commentText:sia.polarity_scores(commentText))
    dataset['compound']=dataset['scores'].apply(lambda score_dict:score_dict['compound'])
    dataset['positive']=dataset['scores'].apply(lambda score_dict:score_dict['pos'])
    dataset['neutral']=dataset['scores'].apply(lambda score_dict:score_dict['neu'])
    dataset['negative']=dataset['scores'].apply(lambda score_dict:score_dict['neg'])
    "Creating final pos or neg using compound score"
    dataset['comp_score']=dataset['compound'].apply(lambda c:'pos' if c>=0 else 'neg')
    plt.clf()
    #comp=sns.countplot(x='comp_score',hue='Name',data=data,palette='magma')
    #comp.figure.savefig("date_charts.png")
    "Checking how many pos or neg"
    posneg=pd.DataFrame(dataset['comp_score'].value_counts())
    return posneg,dataset

# %%
pos,dataset_senti=sentimentalAnalysis(dataset,columnName='Chat')
# Out:
# C:\Anaconda\envs\ai\lib\site-packages\pandas\util\_decorators.py:311: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return func(*args, **kwargs)
# C:\Anaconda\envs\ai\lib\site-packages\ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   del sys.path[0]
# C:\Anaconda\envs\ai\lib\site-packages\ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
dataset_senti
# Out:
#        Date        Time          Name  \
# 1    1/6/23    9:39 AM    Elil Greens
# 2    1/6/23    9:39 AM    Elil Greens
# 3    1/6/23    9:39 AM    Elil Greens
# 4    1/6/23   10:05 AM              🌚
# 5    1/6/23   10:08 AM    Elil Greens
# ..      ...         ...           ...
# 111  3/3/23    7:11 PM              🌚
# 112  3/3/23    7:20 PM              🌚
# 113  3/3/23    7:49 PM              🌚
# 114  3/5/23    9:26 PM    Elil Greens
# 115  3/5/23    9:48 PM              🌚
#
#                                          Chat  \
# 1                                          Hi
# 2     I am Ezhilarasan from Greens technology
# 3                When will u free pls call me
# 4                 Pls give the python content
# 5                                          ok
# ..                                        ...
# 111                                  Sir link
# 112                                      Sir
# 113                                      Sir
# ...

# %%
pos
# Out:
#      comp_score
# pos          62
# neg           4

# %%
#This is positive conversation

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
tfidf=TfidfVectorizer(max_df=0.95,min_df=2,stop_words='english')
dtm=tfidf.fit_transform(df["Chat"])

# %%
dtm
# Out:
# <66x24 sparse matrix of type '<class 'numpy.float64'>'
# 	with 91 stored elements in Compressed Sparse Row format>

# %%
from sklearn.decomposition import NMF
nmf_model=NMF(n_components=5,random_state=42)
nmf_model.fit(dtm)
# Out:
# C:\Anaconda\envs\ai\lib\site-packages\sklearn\decomposition\_nmf.py:294: FutureWarning: The 'init' value, when 'init=None' and n_components is less than n_samples and n_features, will be changed from 'nndsvd' to 'nndsvda' in 1.1 (renaming of 0.26).
#   FutureWarning,
# NMF(n_components=5, random_state=42)

# %%
for index,topic in enumerate (nmf_model.components_):
    results=([tfidf.get_feature_names()[i] for i in topic.argsort()[-10:]])
    print(results)
# Out:
# ['belowdetails', 'ok', 'today', 'irukka', 'share', 'meeting', 'message', 'link', 'hello', 'sir']
# ['hello', 'free', 'demo', 'contacts', 'belowdetails', 'kindly', 'class', 'sir', 'attend', 'ok']
# ['hi', 'hello', 'free', 'demo', 'contacts', 'class', 'belowdetails', 'kindly', 'sir', 'yes']
# ['regarding', 'need', 'link', 'tomorrow', 'meeting', 'demo', 'irukka', 'attend', 'today', 'class']
# ['tomorrow', 'contacts', 'free', 'python', 'message', 'pls', 'belowdetails', 'need', 'kindly', 'share']
# C:\Anaconda\envs\ai\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)

# %%
topic_results=nmf_model.transform(dtm)
df["Topic"]=topic_results.argmax(axis=1)
# Out:
# C:\Anaconda\envs\ai\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df
# Out:
#        Date        Time          Name  \
# 1    1/6/23    9:39 AM    Elil Greens
# 2    1/6/23    9:39 AM    Elil Greens
# 3    1/6/23    9:39 AM    Elil Greens
# 4    1/6/23   10:05 AM              🌚
# 5    1/6/23   10:08 AM    Elil Greens
# ..      ...         ...           ...
# 111  3/3/23    7:11 PM              🌚
# 112  3/3/23    7:20 PM              🌚
# 113  3/3/23    7:49 PM              🌚
# 114  3/5/23    9:26 PM    Elil Greens
# 115  3/5/23    9:48 PM              🌚
#
#                                          Chat  \
# 1                                          Hi
# 2     I am Ezhilarasan from Greens technology
# 3                When will u free pls call me
# 4                 Pls give the python content
# 5                                          ok
# ..                                        ...
# 111                                  Sir link
# 112                                      Sir
# 113                                      Sir
# ...

# %% [markdown]
# # Flirt Prediction

# %%
df.to_csv('whatsapp_data.csv', index=False)

# %%
import pandas as pd
#from sklearn.model_selection import train_test_split
#from sklearn.feature_extraction.text import TfidfVectorizer
#from sklearn.linear_model import LogisticRegression
#from sklearn.metrics import accuracy_score

# Step 1: Read the WhatsApp chat data
df = pd.read_csv('whatsapp_data.csv')

# Display the first few rows to understand the structure
print(df.head())

# Step 2: Define labels based on criteria (example: using sentiment scores)
def classify_flirtatious(compound_score):
    # Example criteria: classify as flirtatious if compound score is high
    if compound_score >= 0.5:
        return 'yes'
    else:
        return 'no'

# Apply classification function to each row
df['flirt_prediction'] = df['compound'].apply(classify_flirtatious)

# Display the predicted results
print("Predicted Flirtatious Messages:")
print(df[['Date', 'Time', 'Name', 'Chat', 'flirt_prediction']])

# Optionally, you can save the results to a new CSV file
#df.to_csv('whatsapp_data_with_flirt_predictions.csv', index=False)
# Out:
#      Date        Time          Name                                      Chat  \
# 0  1/6/23    9:39 AM    Elil Greens                                        Hi
# 1  1/6/23    9:39 AM    Elil Greens   I am Ezhilarasan from Greens technology
# 2  1/6/23    9:39 AM    Elil Greens              When will u free pls call me
# 3  1/6/23   10:05 AM              🌚               Pls give the python content
# 4  1/6/23   10:08 AM    Elil Greens                                        ok
#
#                                               scores  compound  positive  \
# 0  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000     0.000
# 1  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000     0.000
# 2  {'neg': 0.0, 'neu': 0.465, 'pos': 0.535, 'comp...    0.5574     0.535
# 3  {'neg': 0.0, 'neu': 0.755, 'pos': 0.245, 'comp...    0.0772     0.245
# 4  {'neg': 0.0, 'neu': 0.0, 'pos': 1.0, 'compound...    0.2960     1.000
#
#    neutral  negative comp_score  Topic
# ...

# %%
df
# Out:
#       Date        Time          Name  \
# 0   1/6/23    9:39 AM    Elil Greens
# 1   1/6/23    9:39 AM    Elil Greens
# 2   1/6/23    9:39 AM    Elil Greens
# 3   1/6/23   10:05 AM              🌚
# 4   1/6/23   10:08 AM    Elil Greens
# ..     ...         ...           ...
# 61  3/3/23    7:11 PM              🌚
# 62  3/3/23    7:20 PM              🌚
# 63  3/3/23    7:49 PM              🌚
# 64  3/5/23    9:26 PM    Elil Greens
# 65  3/5/23    9:48 PM              🌚
#
#                                         Chat  \
# 0                                         Hi
# 1    I am Ezhilarasan from Greens technology
# 2               When will u free pls call me
# 3                Pls give the python content
# 4                                         ok
# ..                                       ...
# 61                                  Sir link
# 62                                      Sir
# 63                                      Sir
# 64                                   Hai all
# ...

# %% [markdown]
# # Talkative & Less talkative

# %%
# Step 1: Read the WhatsApp chat data
df = pd.read_csv('whatsapp_data.csv')

# Display the first few rows to understand the structure
print(df.head())

# Step 2: Define labels based on criteria (example: message length)
def classify_talkativeness(message):
    # Example criteria: classify as talkative if message length is long
    if len(message.split()) >= 5:
        return 'talkative'
    else:
        return 'less talkative'

# Apply classification function to each row
df['talkativeness_prediction'] = df['Chat'].apply(classify_talkativeness)

# Display the predicted results
print("Predicted Talkativeness:")
print(df[['Date', 'Time', 'Name', 'Chat', 'talkativeness_prediction']])

# Optionally, you can save the results to a new CSV file
#df.to_csv('whatsapp_data_with_talkativeness_predictions.csv', index=False)
# Out:
#      Date        Time          Name                                      Chat  \
# 0  1/6/23    9:39 AM    Elil Greens                                        Hi
# 1  1/6/23    9:39 AM    Elil Greens   I am Ezhilarasan from Greens technology
# 2  1/6/23    9:39 AM    Elil Greens              When will u free pls call me
# 3  1/6/23   10:05 AM              🌚               Pls give the python content
# 4  1/6/23   10:08 AM    Elil Greens                                        ok
#
#                                               scores  compound  positive  \
# 0  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000     0.000
# 1  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000     0.000
# 2  {'neg': 0.0, 'neu': 0.465, 'pos': 0.535, 'comp...    0.5574     0.535
# 3  {'neg': 0.0, 'neu': 0.755, 'pos': 0.245, 'comp...    0.0772     0.245
# 4  {'neg': 0.0, 'neu': 0.0, 'pos': 1.0, 'compound...    0.2960     1.000
#
#    neutral  negative comp_score  Topic
# ...

# %%
df
# Out:
#       Date        Time          Name  \
# 0   1/6/23    9:39 AM    Elil Greens
# 1   1/6/23    9:39 AM    Elil Greens
# 2   1/6/23    9:39 AM    Elil Greens
# 3   1/6/23   10:05 AM              🌚
# 4   1/6/23   10:08 AM    Elil Greens
# ..     ...         ...           ...
# 61  3/3/23    7:11 PM              🌚
# 62  3/3/23    7:20 PM              🌚
# 63  3/3/23    7:49 PM              🌚
# 64  3/5/23    9:26 PM    Elil Greens
# 65  3/5/23    9:48 PM              🌚
#
#                                         Chat  \
# 0                                         Hi
# 1    I am Ezhilarasan from Greens technology
# 2               When will u free pls call me
# 3                Pls give the python content
# 4                                         ok
# ..                                       ...
# 61                                  Sir link
# 62                                      Sir
# 63                                      Sir
# 64                                   Hai all
# ...

# %% [markdown]
# # Most active time ,date ,hours

# %%
# Step 1: Read the WhatsApp chat data
df = pd.read_csv('whatsapp_data.csv')

# Display the first few rows to understand the structure
print(df.head())

# Step 2: Convert 'Date' and 'Time' to datetime format
df['DateTime'] = pd.to_datetime(df['Date'] + ' ' + df['Time'])

# Step 3: Extract day of the week and hour of the day
df['DayOfWeek'] = df['DateTime'].dt.day_name()
df['HourOfDay'] = df['DateTime'].dt.hour

# Step 4: Calculate activity metrics
most_active_day = df['DayOfWeek'].mode()[0]  # Mode gives the most frequent value
most_active_time = df['HourOfDay'].mode()[0]  # Mode gives the most frequent value

# Display results
print(f"Most Active Day: {most_active_day}")
print(f"Most Active Time: {most_active_time}:00 - {most_active_time + 1}:00")
# Out:
#      Date        Time          Name                                      Chat  \
# 0  1/6/23    9:39 AM    Elil Greens                                        Hi
# 1  1/6/23    9:39 AM    Elil Greens   I am Ezhilarasan from Greens technology
# 2  1/6/23    9:39 AM    Elil Greens              When will u free pls call me
# 3  1/6/23   10:05 AM              🌚               Pls give the python content
# 4  1/6/23   10:08 AM    Elil Greens                                        ok
#
#                                               scores  compound  positive  \
# 0  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000     0.000
# 1  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000     0.000
# 2  {'neg': 0.0, 'neu': 0.465, 'pos': 0.535, 'comp...    0.5574     0.535
# 3  {'neg': 0.0, 'neu': 0.755, 'pos': 0.245, 'comp...    0.0772     0.245
# 4  {'neg': 0.0, 'neu': 0.0, 'pos': 1.0, 'compound...    0.2960     1.000
#
#    neutral  negative comp_score  Topic
# ...

# %%
df
# Out:
#       Date        Time          Name  \
# 0   1/6/23    9:39 AM    Elil Greens
# 1   1/6/23    9:39 AM    Elil Greens
# 2   1/6/23    9:39 AM    Elil Greens
# 3   1/6/23   10:05 AM              🌚
# 4   1/6/23   10:08 AM    Elil Greens
# ..     ...         ...           ...
# 61  3/3/23    7:11 PM              🌚
# 62  3/3/23    7:20 PM              🌚
# 63  3/3/23    7:49 PM              🌚
# 64  3/5/23    9:26 PM    Elil Greens
# 65  3/5/23    9:48 PM              🌚
#
#                                         Chat  \
# 0                                         Hi
# 1    I am Ezhilarasan from Greens technology
# 2               When will u free pls call me
# 3                Pls give the python content
# 4                                         ok
# ..                                       ...
# 61                                  Sir link
# 62                                      Sir
# 63                                      Sir
# 64                                   Hai all
# ...

# %% [markdown]
# # Media Count

# %%
# Step 1: Read the WhatsApp chat data
df = pd.read_csv('whatsapp_data.csv')

# Display the first few rows to understand the structure
print(df.head())

# Step 2: Define function to identify media messages
def media_message(chat_text):
    return '<Media omitted>' in str(chat_text)  # Check if message contains media indicator

# Step 3: Mark messages containing media
df['Media SR count'] = df['Chat'].apply(media_message)

# Step 4: Group by 'Name' and count media messages
media_counts = df[df['Media SR count']].groupby('Name').size().reset_index(name='MediaCount')

# Display results
print("Media Counts:")
print(media_counts)
# Out:
#      Date        Time          Name                                      Chat  \
# 0  1/6/23    9:39 AM    Elil Greens                                        Hi
# 1  1/6/23    9:39 AM    Elil Greens   I am Ezhilarasan from Greens technology
# 2  1/6/23    9:39 AM    Elil Greens              When will u free pls call me
# 3  1/6/23   10:05 AM              🌚               Pls give the python content
# 4  1/6/23   10:08 AM    Elil Greens                                        ok
#
#                                               scores  compound  positive  \
# 0  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000     0.000
# 1  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000     0.000
# 2  {'neg': 0.0, 'neu': 0.465, 'pos': 0.535, 'comp...    0.5574     0.535
# 3  {'neg': 0.0, 'neu': 0.755, 'pos': 0.245, 'comp...    0.0772     0.245
# 4  {'neg': 0.0, 'neu': 0.0, 'pos': 1.0, 'compound...    0.2960     1.000
#
#    neutral  negative comp_score  Topic
# ...

# %%
df
# Out:
#       Date        Time          Name  \
# 0   1/6/23    9:39 AM    Elil Greens
# 1   1/6/23    9:39 AM    Elil Greens
# 2   1/6/23    9:39 AM    Elil Greens
# 3   1/6/23   10:05 AM              🌚
# 4   1/6/23   10:08 AM    Elil Greens
# ..     ...         ...           ...
# 61  3/3/23    7:11 PM              🌚
# 62  3/3/23    7:20 PM              🌚
# 63  3/3/23    7:49 PM              🌚
# 64  3/5/23    9:26 PM    Elil Greens
# 65  3/5/23    9:48 PM              🌚
#
#                                         Chat  \
# 0                                         Hi
# 1    I am Ezhilarasan from Greens technology
# 2               When will u free pls call me
# 3                Pls give the python content
# 4                                         ok
# ..                                       ...
# 61                                  Sir link
# 62                                      Sir
# 63                                      Sir
# 64                                   Hai all
# ...

# %% [markdown]
# # Missed call count

# %%
import pandas as pd

# Step 1: Read the WhatsApp chat data
df = pd.read_csv('whatsapp_data.csv')

# Display the first few rows to understand the structure
print(df.head())

# Step 2: Define function to identify missed call messages
def is_missed_call(chat_text):
    chat_lower = str(chat_text).lower()
    return 'missed call' in chat_lower or 'call back' in chat_lower

# Step 3: Count missed call messages
missed_call_count = df[df['Chat'].apply(lambda x: is_missed_call(x))].shape[0]

# Display results
print(f"Total Missed Calls: {missed_call_count}")
print(missed_call_counts)
# Out:
#      Date        Time          Name                                      Chat  \
# 0  1/6/23    9:39 AM    Elil Greens                                        Hi
# 1  1/6/23    9:39 AM    Elil Greens   I am Ezhilarasan from Greens technology
# 2  1/6/23    9:39 AM    Elil Greens              When will u free pls call me
# 3  1/6/23   10:05 AM              🌚               Pls give the python content
# 4  1/6/23   10:08 AM    Elil Greens                                        ok
#
#                                               scores  compound  positive  \
# 0  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000     0.000
# 1  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000     0.000
# 2  {'neg': 0.0, 'neu': 0.465, 'pos': 0.535, 'comp...    0.5574     0.535
# 3  {'neg': 0.0, 'neu': 0.755, 'pos': 0.245, 'comp...    0.0772     0.245
# 4  {'neg': 0.0, 'neu': 0.0, 'pos': 1.0, 'compound...    0.2960     1.000
#
#    neutral  negative comp_score  Topic
# ...
